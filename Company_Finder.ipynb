# %% [markdown]
# # Company finder based on user's current job
#
#
# ## Goal:
#
# Search for people that attended Machine learning, data science or data analytics internships or junior positions around Europe. Filter by company size. The objective is to find a list of companies that hire for such positions. I will also leave a count of repetitive positions in the same company, as it helps decide which companies to put on the watchlist.

# %% [markdown]
# To get people from linkedin, I will use tom quirk's unofficial [linkedin api](https://github.com/tomquirk/linkedin-api)
# I will also use `dotenv` to load the username/password safely. Create a `.env` file and populate it with environmental variables that you don't want others to see or for cleaner scripts.

# %%
import re
import os
from diskcache import Cache
from linkedin_api import Linkedin
from utils.helper import *

# %load_ext dotenv
# %dotenv

LINKEDIN_USERNAME = os.environ.get("LINKEDIN_USERNAME")
LINKEDIN_PASSWORD = os.environ.get("LINKEDIN_PASSWORD")

linkedin = Linkedin(LINKEDIN_USERNAME, LINKEDIN_PASSWORD)

# %% [markdown]
# ### Get the search results, NOT cached
#
# Regions codes: https://developer.linkedin.com/docs/reference/geography-codes
# To obtain other codes, see https://i.imgur.com/lcHeXRa.png
#
# Translation:
#     nl:0 means all NL
#     de:4944 means Berlin Area in Germany
#
# See https://github.com/tomquirk/linkedin-api/blob/252add3bda1a9ce1f50fcd5419aac05dbf81498c/linkedin_api/linkedin.py#L113 for more about the params.

# %%
# raise Exception("Comment me out if you want to load new data")

results = linkedin.search_people(
    keywords='Junior data analyst',
    regions=["nl:0", "de:0", "fr:0", "gb:0", "es:0", "ch:0", "dk:0", "fi:0", "pt:0", "se:0", "be:0"],
    profile_languages=['en'],
    limit=(49 * 1),  # limit is 49 per page, so we get multiples of that
#     network_depth="O"
)

print(f"{len(results)} results retrieved")
# Out:
# 49 results retrieved

# %% [markdown]
# ### Get each user profile from cached, if not cached, make an api call and save it in cache
#
# Now we loop them, using DiskCache (./cache.db), used with no expiry on the objects.

# %%
found = []

# the cache has all the users, you can loop those without loading everytime
# cache saved in ./cache.db
with Cache("./") as cache:
    i = 0
    for res in results:
        cache_id = res["urn_id"]
        i += 1
        
        if cache_id not in cache:
            print(f"Miss, getting profile from API and saving {i}/{len(results)}")
            profile = linkedin.get_profile(urn_id=res["urn_id"])
            cache.set(cache_id, profile)
            headline = profile['headline'] if 'headline' in profile else ''
            print(f"Miss, get+save: {profile['lastName']} [{headline}] from {profile['locationName']}")
        else:
            print("Hit, getting profile from cache")
            profile = cache.get(cache_id)
        
        match = chk_match(profile["experience"], verbose=True)
        if(match):
            found.append(res)
        
print(f"\n\n\n{len(found)} users found")
# Out:
# Hit, getting profile from cache
# Hit, getting profile from cache
#
# ---
# Junior Data Analyst @ WonderLoudly (None)
# ?, size Berlin Metropolitan Area
# from 0 to {'month': 1, 'year': 2020}
# id: ?
#
# Description: Building and developing custom made data analytics products tailored  make for the clients' need
# Such as:
# - Activity monitoring dashboards using Python(Matplotlib, Numpy)
# - Data migration tool using Python APIs  (Monday, Google drive, Tableau)
# - CV  analysis tool using Python NLP libraries
# ---
#
# Hit, getting profile from cache
# Miss, getting profile from API and saving 4/49
# Miss, get+save: Rodari [Junior Data Analyst] from Frankfurt am Main, Hessen, Germany
# Hit, getting profile from cache
# Miss, getting profile from API and saving 6/49
# Miss, get+save: Llana Ben [Junior Data Analyst at Meister] from Berlin, Berlin, Germany
#
# ---
# Junior Data Analyst @ Meister (urn:li:fs_miniCompany:613998)
# Internet, size Vienna, Austria
# from 51 to {'month': 6, 'year': 2020}
# id: ?
# ---
#
# Miss, getting profile from API and saving 7/49
# Miss, get+save: O. [Data & Analytics] from Germany
#
# ---
# Data Scientist - Trainee @ Ubiqum Code Academy (urn:li:fs_miniCompany:3011456)
# Internet, size Germany
# from 11 to {'month': 2, 'year': 2019}
# id: {'month': 7, 'year': 2019}
#
# Description: •	Agile/Scrum methodology.
# •	Data mining and pattern recognition: Understanding customers’ behaviour, predicting customers' brand preference and future profitability.
# •	Market Basket Analysis: Discovering purchase patterns, such a combination of items that occur together frequently in transactions.
# •	Time Series Analysis and Visualization with Tableau, Matplotlib, and PyPlot: Forecasting household energy consumption based on usage patterns of residential householders. (IoT SmartHome).
# •	WiFi Fingerprinting Indoor Localization: Applying multiple machine learning models on the Received Signals Strength Intensity (RSSI) from multiple wifi hotspots within the building to determine location. See less
# •	Analysed hit songs with Spotify’s Web API to find audio feature patterns.
# •	Creating custom SQL reports for data analysis.
# •	Developed facial detection application with Python library.
#
# ---
#
# Hit, getting profile from cache
#
# ---
# Junior Data Analyst @ E.ON Energie Deutschland GmbH (urn:li:fs_miniCompany:9595025)
# ?, size Potsdam Area, Germany
# from 11 to {'month': 9, 'year': 2019}
# id: ?
#
# Description: * Developing database queries and PowerBI reports on KPIs by data wrangling in Microsoft SQL Server in Customer Contact Management Area
# * Supporting business stakeholders by conducting ad-hoc data analysis
# ---
#
# Hit, getting profile from cache
# Hit, getting profile from cache
# Hit, getting profile from cache
#
# ---
# Junior Data Analyst @ Data Mining Solutions (None)
# ?, size Moscow, Russian Federation
# from 0 to {'month': 12, 'year': 2017}
# id: {'month': 4, 'year': 2019}
#
# Description: Machine learning in Natural Language Processing:
# - development of a prototype of a machine learning algorithm for question answering system
# - web-scraping and assembly of training and testing datasets
# - development of a machine learning algorithm for service implementation with Keras framework
# - accuracy tests of the algorithm
# - preparing the sequence labeled dataset
# - training the LSTM aimed to recognize certain sequences of words in texts
# - information retrieval from unstructured data
# ---
#
# Hit, getting profile from cache
# Hit, getting profile from cache
#
# ---
# Junior Data Analyst @ FocusEconomics (urn:li:fs_miniCompany:597617)
# Information Services, size Barcelona Area, Spain
# from 11 to {'month': 8, 'year': 2018}
# id: ?
# ---
#
# Hit, getting profile from cache
# Hit, getting profile from cache
#
# ---
# Junior Data Analyst @ Ruditel (urn:li:fs_miniCompany:28176633)
# Computer Software, size unknown
# from 2 to {'month': 8, 'year': 2018}
# id: {'month': 12, 'year': 2019}
#
# Description:  - Working remotely as a part of Data Analytics team for a Miami-based startup
#  - Assisting Senior Data Specialist in creating product requirements and specifications
#  - Compiling, organizing and analyzing data
#  - Data preparation
# ---
#
# Miss, getting profile from API and saving 16/49
# Miss, get+save: Mascia [Junior Data Analyst at citizenM hotels] from Leiden, South Holland Province, Netherlands
#
# ---
# Data Science Intern @ e.fundamentals (urn:li:fs_miniCompany:9259099)
# Information Technology and Services, size Edinburgh, United Kingdom
# from 11 to {'month': 6, 'year': 2019}
# id: {'month': 8, 'year': 2019}
#
# Description: MSc Dissertation project. Using Python to combine NLP with Machine Learning and develop a text-based classification model, addressed to automatize the product categorization procedure.
# ---
#
# Hit, getting profile from cache
# Hit, getting profile from cache
#
# ---
# Junior Data Analyst @ Vision11 GmbH (urn:li:fs_miniCompany:2092041)
# Marketing and Advertising, size München
# from 51 to {'month': 2, 'year': 2018}
# id: ?
# ---
#
# Hit, getting profile from cache
#
# ---
# Data Analytics & Machine Learning  Trainee @ Ubiqum Code Academy (urn:li:fs_miniCompany:3011456)
# Internet, size Berlin Area, Germany
# from 11 to {'month': 10, 'year': 2018}
# id: {'month': 3, 'year': 2019}
#
# Description: •Agile/Scrum methodology
# •Data mining: Understanding customers’ behaviour, predicting customers’s brand preference and future profitability.
# •Market Basket Analysis: Discovering purchase patterns, such a combinations of items that occur together frequently in transactions.
# •Time Series Analysis and Visualization with Shiny Dashboard: Forecasting household energy consumption based on usage patterns of residential householders. (IoT SmartHome).
# •WiFi Fingerprinting Indoor Localization: Applying multiple machine learning models on the Received Signals Strength Intensity (RSSI) from multiple wifi hotspots within the building to determine location. •Cloud-based Big Data solutions: Sentiment analysis on AWS.
# ---
#
# Miss, getting profile from API and saving 20/49
# Miss, get+save: Marticke [Junior Data & Demand Analyst @ SAP] from Switzerland
# Hit, getting profile from cache
# Hit, getting profile from cache
#
# ---
# Junior Data Analyst @ Goodgame Studios (urn:li:fs_miniCompany:979995)
# Computer Games, size Hamburg Area, Germany
# from 201 to {'month': 8, 'year': 2018}
# id: ?
#
# Description: ► Created and maintained multiple Tableau dashboards (hosted on Tableau Server) for use in marketing optimisation.
# ► Wrote multiple production level ETLs using SQL to transform raw data into usable data sources.
# ► Performed multiple ad-hoc analyses for various stakeholders throughout the company ranging from Bayesian AB Testing to using machine learning (ML) algorithms (Decision Trees/Logistic Regression) to help drive business decisions.
# ► Was the primary point of contact for internal stakeholders, required strong communication and customer service skills.
# ---
#
# Hit, getting profile from cache
#
# ---
# Junior Data Analyst @ auteon (urn:li:fs_miniCompany:14006600)
# Automotive, size Berlin, Germany
# from 11 to {'month': 4, 'year': 2020}
# id: ?
#
# Description: • Design and develop a data science platform to manage data, train, evaluate, deploy models, make predictions, and monitor predictions
# • Lead development and implementation of scalable solutions
# • Handle challenges associated with investigating and understanding large datasets, and building models based on Big Data solutions
# • Mine and analyze data from company databases to drive optimization and improvement of product development
# • Assess the effectiveness and accuracy of new data sources and data gathering techniques
# • Develop custom data models and algorithms to apply to data sets
# • Use predictive modeling to increase and optimize customer experiences and other business outcomes
# • Coordinate with different functional teams to implement models and monitor outcomes
# • Develop data mining, machine learning, statistical and graph-based algorithms designed to analyze massive data sets for business insights
# ---
#
# Miss, getting profile from API and saving 24/49
# Miss, get+save: Conesa Goicoechea [Data Analyst ] from Barcelona, Catalonia, Spain
# Miss, getting profile from API and saving 25/49
# Miss, get+save: Shilovskaya [Data Analyst(Junior)] from Berlin, Berlin, Germany
# Hit, getting profile from cache
# Miss, getting profile from API and saving 27/49
# Miss, get+save: Lopez Ruiz [Data Analyst | Telecom Engineer] from Spain
#
# ---
# Junior Data Analyst @ Ubiqum Code Academy (urn:li:fs_miniCompany:3011456)
# Internet, size Barcelona Area, Spain
# from 11 to {'month': 10, 'year': 2017}
# id: {'month': 3, 'year': 2018}
#
# Description: Development of real business-case projects with real data within a 800 hours full-time intensive course following the learning-by-doing methodology. Strong background in R as well as in fundamentals of statistics.
#
# The business-cases analyzed are:
# - Customers' patterns
# - Cross-selling recommendations
# - Prediction of profitability
# - Discovery of energy consumption patterns
# - Indoor locationing using Wi-Fi fingerprints
# - Sentiment analysis
#
# The main techniques and tools used to carry out these projects were:
# - R language / RStudio (readr, caret, ggplot2, dplyr, tidyr, lubridate)
# - Amazon Web Services - Elastic Map Reduce
# - Machine Learning for Classification and Regression
# - Creation and optimization of predictive models
# ---
#
# Miss, getting profile from API and saving 28/49
# Miss, get+save: Gjikopulli [Junior Data Analyst at combyne] from Munich, Bavaria, Germany
#
# ---
# Junior Data Analyst @ combyne (urn:li:fs_miniCompany:5351133)
# Computer Software, size Munich Area, Germany
# from 11 to {'month': 12, 'year': 2018}
# id: ?
#
# Description: Core Competences:
# - Planning of Upcoming App-Interactivity Tracking; Modification/Adoption of Existing Ones
# - Analysis and Interpretation of Various Product Matrix, such as User Engagement, Retention etc.
# - Design, Creation and Delivery of Market-Intelligent Reports for B2B Company Customers
# ---
#
# Miss, getting profile from API and saving 29/49
# Miss, get+save: Jasná [Business Intelligence Analyst/Developer at tausendkind GmbH] from Berlin Friedrichshain, Berlin, Germany
#
# ---
# Data Analyst Trainee @ Ubiqum Code Academy (urn:li:fs_miniCompany:3011456)
# Internet, size Berlin Area, Germany
# from 11 to {'month': 9, 'year': 2018}
# id: {'month': 2, 'year': 2019}
#
# Description: Data Analytics & Machine Learning, Immersive full-time Data Science bootcamp
#
# Investigating customer buying patterns and predicting sales volume
# Predicting customer brand preference and predicting sales volume
# Discovering data associations between products, Market Basket Analysis
# Analysing sub-metered household data (Forecasting a Time Series)
# Techniques for Wi-Fi locationing
#
# ---
#
# Hit, getting profile from cache
# Miss, getting profile from API and saving 31/49
# Miss, get+save: Rohilla [Junior Data Analyst at EMnify] from Berlin, Berlin, Germany
#
# ---
# Junior Data Analyst @ EMnify (urn:li:fs_miniCompany:5131340)
# Telecommunications, size unknown
# from 51 to {'month': 4, 'year': 2020}
# id: ?
# ---
#
# Miss, getting profile from API and saving 32/49
# Miss, get+save: Matheis [Data analyst at Autoscout 24] from Germany
# Miss, getting profile from API and saving 33/49
# Miss, get+save: Giannakakis [Junior Data Analyst at LetsBuild] from Brussels, Brussels Capital Region, Belgium
#
# ---
# Junior Data Analyst @ LetsBuild (urn:li:fs_miniCompany:3001076)
# Computer Software, size Belgium
# from 51 to {'month': 11, 'year': 2019}
# id: ?
# ---
#
# Miss, getting profile from API and saving 34/49
# Miss, get+save: Vehbiu [Analytical developer] from Netherlands
#
# ---
# Junior Data Analyst @ ReelMetrics (urn:li:fs_miniCompany:18053533)
# Gambling & Casinos, size Leiden, Netherlands
# from 11 to {'month': 5, 'year': 2019}
# id: ?
#
# Description: Tools - Pentaho ETL, PostgreSQL, Vertica, Pandas, Numpy, Plotly, Javascript, Weka,       Kubernetes, Docker, TeamCity, ElasticSearch
#
# Cleaning, reconciling and analyzing one of the world's 'dirtiest' data set; the casino industry.
#
# Back-end development to fuel Reelmetrics analytical platform in order to give reliable information and actionable insights.
#
# Lately, helping to build machine learning models for ranking, recommendations and life cycle prediction.
#
# Building the back-end for creating and processing the results of surveys to help clean our data even further. Also creating the front-end using survey.js
#
# Creating Dash app to streamline any kind of analysis. Creating dynamic SQL and dynamic functions.
# ---
#
# Miss, getting profile from API and saving 35/49
# Miss, get+save: Halder [Junior Data Analyst | Windows Consumer Suites] from Meckenbeuren, Baden-Württemberg, Germany
#
# ---
# Junior Data Analyst @ Avira (urn:li:fs_miniCompany:34316)
# Computer & Network Security, size Tettnang, Baden-Württemberg
# from 201 to {'month': 4, 'year': 2020}
# id: ?
# ---
#
# Miss, getting profile from API and saving 36/49
# Miss, get+save: Tayoun [Junior Data Scientist  at Oerlikon Digital Hub] from Germany
# Miss, getting profile from API and saving 37/49
# Miss, get+save: Pratumchan [Junior Data Analyst & International wish assistance at Make-A-Wish International] from Oog in Al, Utrecht Province, Netherlands
#
# ---
# Junior Data Analyst @ Make-A-Wish International (urn:li:fs_miniCompany:1110758)
# Nonprofit Organization Management, size Hilversum, North Holland, Netherlands
# from 11 to {'month': 2, 'year': 2020}
# id: ?
# ---
#
# Miss, getting profile from API and saving 38/49
# Miss, get+save: Lam [Junior Data Analyst at CHECK24 Vergleichsportal GmbH] from Munich, Bavaria, Germany
# Miss, getting profile from API and saving 39/49
# Miss, get+save: Knobloch [Data Analyst at idealo] from Germany
# Miss, getting profile from API and saving 40/49
# Miss, get+save: Prpić [Junior Data Analyst @ Wunderflats] from Germany
#
# ---
# Junior Data Analyst @ Wunderflats (urn:li:fs_miniCompany:9284910)
# Real Estate, size Berlin Area, Germany
# from 51 to {'month': 10, 'year': 2019}
# id: ?
# ---
#
# Miss, getting profile from API and saving 41/49
# Miss, get+save: Kopellaj [Junior Data Analyst at Wunderflats] from Berlin, Berlin, Germany
#
# ---
# Junior Data Analyst @ Wunderflats (urn:li:fs_miniCompany:9284910)
# Real Estate, size Berlin Area, Germany
# from 51 to {'month': 1, 'year': 2020}
# id: ?
# ---
#
# Miss, getting profile from API and saving 42/49
# Miss, get+save: Neto [Junior Data Science at Fujitsu Portugal] from Barcelona, Catalonia, Spain
# Hit, getting profile from cache
# Miss, getting profile from API and saving 44/49
# Miss, get+save: Bousrih [Junior Data Analyst at Homelike] from Berlin, Berlin, Germany
#
# ---
# ML & AI Engineer Intern @ MBition GmbH (urn:li:fs_miniCompany:27204950)
# Information Technology and Services, size Berlin, Germany
# from 201 to {'month': 3, 'year': 2019}
# id: {'month': 12, 'year': 2019}
# ---
#
# Hit, getting profile from cache
# Miss, getting profile from API and saving 46/49
# Miss, get+save: Sagristà Esteba [Data Analyst at Fluidra] from Barcelona, Catalonia, Spain
# Miss, getting profile from API and saving 47/49
# Miss, get+save: Mooiman [Junior Data Analyst Digital Trade] from Netherlands
#
# ---
# Junior Data Analyst @ HvA Centre for Market Insights  (urn:li:fs_miniCompany:11362799)
# Research, size Amsterdam Area, Netherlands
# from 11 to {'month': 9, 'year': 2019}
# id: ?
# ---
#
# Hit, getting profile from cache
#
# ---
# Junior data analyst @ Paazl (urn:li:fs_miniCompany:3197109)
# Computer Software, size unknown
# from 11 to {'month': 2, 'year': 2020}
# id: ?
# ---
#
# Miss, getting profile from API and saving 49/49
# Miss, get+save: Orujova [Big Data Analyst at trivago] from Germany
#
#
#
# 25 users found

# %% [markdown]
# ### To avoid suspending your LinkedIn account, always use the cache and avoid making extra calls to linkedin

# %%
found = []
found_companies = {}

# the cache has all the users, you can loop those without loading everytime

with Cache("./") as cache:
    for key in cache:        
        profile = cache.get(key)        
        exp = chk_match(profile['experience'], verbose=False)
        
        if exp:
            found.append(profile)
            cid = exp["companyName"]
            
            if cid in found_companies: # add
                found_companies[cid]['count'] += 1
                found_companies[cid]['titles'].append(exp["title"])
            else: # new
                found_companies[cid] = {
                    'name': exp["companyName"], 
                    'count': 1, 
                    'id': exp.get("geoUrn", None),

                    'company': exp["company"] if "company" in exp else [], 
                    'locationName': exp["locationName"] if "locationName" in exp else "unknown", 
                    'titles': [exp["title"]]
                }

print(f"\nFound {len(found)} users out of {len(cache)}")
print(f"\nFound {len(found_companies)} companies with jobs matching our search/regex criteria. We can check them out and monitor them for future jobs.")
# Out:
# Found 32 users out of 75
#
# Found 23 companies with jobs matching our search/regex criteria. We can check them out and monitor them for future jobs.
